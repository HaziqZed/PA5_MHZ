# %% [markdown]
# # Programming Assignment 5
# ---
# **Author:** Haziq Zed
# **Version:** 1.0
# **Semester:** Fall 2020
#
# This *notebook* contains my solution to **Programming Assignment 5**
#
# - Problem 1:

# %%
wtranslate=dict()

wtranslate['person']='orang'
wtranslate['food']='makanan'
wtranslate['drink']='minuman'
wtranslate['dog']='anjing'
wtranslate['cat']='kucing'
wtranslate['shirt']='baju'
wtranslate['pants']='seluar'
wtranslate['hat']='topi'
wtranslate['bird']='burung'
wtranslate['sad']='sedih'
wtranslate['happy']='gembira'
wtranslate['help']='tolong'
wtranslate['if']='kalau'
wtranslate['why']='kenapa'
wtranslate['no']='tak'
wtranslate['yes']='iya'
wtranslate['where']='mana'
wtranslate['tall']='tinggi'
wtranslate['short']='pendek'
wtranslate['sing']='menyanyi'

word = ""
while word != "0":
    word = input("Enter a word to translate from English to Malay (enter 0 to stop):")
    check = True
    for english, malay in wtranslate.items():
        if check == True:
            if word in wtranslate:
                check = False
                print(f'The Malay word for {word} is {wtranslate.get(word)}')
            else:
                check = False
                if word != "0":
                    print(f'The Malay word for {word} is not in this dictionary.')
# Out:
# Enter a word to translate from English to Malay (enter 0 to stop):short
# The Malay word for short is pendek
# Enter a word to translate from English to Malay (enter 0 to stop):yes
# The Malay word for yes is iya
# Enter a word to translate from English to Malay (enter 0 to stop):hat
# The Malay word for hat is topi
# Enter a word to translate from English to Malay (enter 0 to stop):sad
# The Malay word for sad is sedih
# Enter a word to translate from English to Malay (enter 0 to stop):cat
# The Malay word for cat is kucing
# Enter a word to translate from English to Malay (enter 0 to stop):food
# The Malay word for food is makanan
# Enter a word to translate from English to Malay (enter 0 to stop):person
# The Malay word for person is orang
# Enter a word to translate from English to Malay (enter 0 to stop):drink
# The Malay word for drink is minuman
# Enter a word to translate from English to Malay (enter 0 to stop):0

# %% [markdown]
# - Problem 2:

# %%
from prettytable import PrettyTable

dnd = dict()

dnd['Bard']=[('Hit Die','d8'),
             ('Primary Ability','Charisma'),
             ('Saves','Dexterity & Charisma'),
             'An inspiring magician whose power echoes the music of creation.']

dnd['Cleric']=[('Hit Die','d8'),
               ('Primary Ability','Wisdom'),
               ('Saves','Wisdom & Charisma'),
             'A pirestly champion who wields divine magic in service of a higher power.']

dnd['Druid']=[('Hit Die','d8'),
              ('Primary Ability','Wisdom'),
              ('Saves','Wisdom & Intelligence'),
             'A pirest of the Old Faith, wielding the powers of nature and adopting animal forms.']

dnd['Fighter']=[('Hit Die','d10'),
                ('Primary Ability','Strength or Dexterity'),
                ('Saves','Strength & Constitution'),
             'A master of martia combat, skilled with a variety of weapons and armor.']

dnd['Paladin']=[('Hit Die','d10'),
                ('Primary Ability','Strength & Charisma'),
                ('Saves','Wisdom & Charisma'),
             'A holy warrior bound to a sacred oath.']

dnd['Rogue']=[('Hit Die','d8'),
              ('Primary Ability','Dexterity'),
              ('Saves','Dexterity & Intelligence'),
             'A scoundrel who uses stealth and trickery to overcome obstacles and enemies.']


name = ''

def print_player_data(player):
    check = 1
    for player,data in dnd.items():
        if check == 1:
            if name in dnd:
                temp = dnd.get(name)
                print(f'Description: {temp[3]}')
                x = PrettyTable()
                x.field_names = (temp[0][0], temp[1][0], temp[2][0])
                x.add_row([temp[0][1], temp[1][1], temp[2][1]])
                print(x)
                check=0
            else:
                check = 0
                print("I have no record of this player class!")
                print('\n')

while name != '0':
    name = input("Enter the class of player you would like to look up. Enter zero (0) to quit. ")
    print('\n')
    if name != '0':
        print_player_data(name)
    else:
        break
# Out:
# Enter the class of player you would like to look up. Enter zero (0) to quit. Bard
#
#
# Description: An inspiring magician whose power echoes the music of creation.
# +---------+-----------------+----------------------+
# | Hit Die | Primary Ability |        Saves         |
# +---------+-----------------+----------------------+
# |    d8   |     Charisma    | Dexterity & Charisma |
# +---------+-----------------+----------------------+
# Enter the class of player you would like to look up. Enter zero (0) to quit. Fighter
#
#
# Description: A master of martia combat, skilled with a variety of weapons and armor.
# +---------+-----------------------+-------------------------+
# | Hit Die |    Primary Ability    |          Saves          |
# +---------+-----------------------+-------------------------+
# |   d10   | Strength or Dexterity | Strength & Constitution |
# +---------+-----------------------+-------------------------+
# ...
